# %%
### importieren
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()  # for plot styling
import numpy as np
from sklearn.datasets.samples_generator import make_blobs #random data generator

# %%
#generate data
X, y_true = make_blobs(n_samples=600, centers=4,
                       cluster_std=0.60, random_state=0)
plt.scatter(X[:, 0], X[:, 1], s=50);

# %%
import WWDKClustering as cl

# %%
test = cl.Kmeans(X)

# %%
test.kmeans()
# Out:
# array([[-1.12108801,  7.84805153],
#        [ 0.97258955,  3.81637811],
#        [-1.38152167,  2.46071377],
#        [ 0.88958497,  4.77434466],
#        [ 1.96979699,  0.08098383],
#        [ 1.31446314,  0.94486898],
#        [ 2.44445932,  1.16248148],
#        [-1.77625886,  3.28698603]])

# %%
test.plot()
