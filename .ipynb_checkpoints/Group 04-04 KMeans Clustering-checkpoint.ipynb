# %% [markdown]
# # Project 04-04: Kmeans Clustering
# *by Thorge Dobbertin, Julia Köberle, Marilena Wittmarck und Benedict Wolf*

# %%
# %matplotlib inline
import matplotlib as mpl
mpl.rcParams['figure.dpi']= 300

# %% [markdown]
# ## WWDK Package

# %% [markdown]
# We created a Package divided itno three modules. The first module *Data* preprocesses our data to make clustering easier. The next module *Cluster* allows one to choose a clustering method to cluster the data. The third module *Utilities* contains useful functions to present the data and compare our Clustering methods against the sklearn implementations

# %%
from wwdk import data as d
from wwdk import cluster as cl
from wwdk import Utilities as u

# %% [markdown]
# ## Kmeans

# %% [markdown]
# The Kmeans class uses the sklearn estimators and cotains the following methods:

# %%
Kmeans(inits=10, k=8, maxit=300, method="++", tol = 1e-3)

# %% [markdown]
# blubb

# %%
Kmeans.fit(data)

# %% [markdown]
# Fits the data

# %%
Kmeans.transform(data)

# %% [markdown]
# Transforms the Dataset into the Point-Cluster Distances of each point

# %%
Kmeans.predict(data)

# %% [markdown]
# ## Minibatch Kmeans

# %% [markdown]
# ## Limits of Kmeans

# %% [markdown]
# ## Pokemon Dataset

# %% [markdown]
# In next step we wanted to analyze a pokemon dataset. This represents a easy to understand and relatively small dataset to test our clustering.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
pkmn = pd.read_csv('Pokemon/pokemon.csv', index_col=0)
pkmn.head()
# Out:
#                     Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# #
# 1              Bulbasaur  Grass  Poison    318  45      49       49       65
# 2                Ivysaur  Grass  Poison    405  60      62       63       80
# 3               Venusaur  Grass  Poison    525  80      82       83      100
# 3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123      122
# 4             Charmander   Fire     NaN    309  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# #
# 1       65     45           1      False
# 2       80     60           1      False
# 3      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %% [markdown]
# As one can see

# %%
from sklearn.decomposition import PCA
from sklearn import preprocessing
from sklearn.manifold import TSNE

red_pkmn = pkmn[["Attack","Defense","Sp. Atk", "Sp. Def","Speed", "Type 1"]]
pkmn_array = np.array(red_pkmn[["Attack","Defense","Sp. Atk", "Sp. Def","Speed"]])

# %% [markdown]
# ### Without Dimensional Reduction

# %%
u.elbow_plot(pkmn_array,30)

# %%
kmeans_without_dr = cl.Kmeans(k=10)
kmeans_without_dr.fit(pkmn_array)
# Out:
# Kmeans(inits=None, k=None, maxit=None, method=None, tol=None)

# %%
pkmn_red =pkmn.drop(["Legendary", "Generation"], axis=1)
pkmn_red["Cluster"] = kmeans_without_dr.labels_

# %%
pkmn_comparer = pkmn_red[pkmn_red.Cluster == 0].mean(axis = 0)
pkmn_final = pd.DataFrame(pkmn_comparer).T
for i in range(9):
    pkmn_red[pkmn_red.Cluster == i+1].mean(axis = 0)
    pkmn_final = pkmn_final.append(pd.DataFrame(pkmn_red[pkmn_red.Cluster == i+1].mean(axis = 0)).T)

pkmn_final.set_index("Cluster").sort_values(by="Total")
# Out:
#               Total         HP      Attack     Defense     Sp. Atk  \
# Cluster
# 5.0      258.876404  53.359551   38.067416   41.752809   39.089888
# 0.0      332.191011  57.067416   69.876404   72.494382   42.606742
# 2.0      337.677419  53.250000   58.887097   45.379032   57.685484
# 8.0      430.132653  78.704082   70.153061   67.469388   83.622449
# 7.0      483.930693  76.524752  104.960396   71.693069   64.504950
# 1.0      487.151515  76.363636  106.909091  115.909091   59.575758
# 3.0      520.173913  79.768116   72.695652   94.579710   98.666667
# 9.0      529.850000  61.250000   74.550000  163.500000   65.550000
# 4.0      533.025000  74.525000   79.812500   72.862500  111.637500
# 6.0      645.187500  90.671875  138.562500   96.109375  127.187500
#
#             Sp. Def       Speed
# Cluster
# 5.0       45.966292   40.640449
# 0.0       51.876404   38.269663
# 2.0       51.088710   71.387097
# 8.0       74.846939   55.336735
# 7.0       71.425743   94.821782
# 1.0       72.121212   56.272727
# 3.0      108.623188   65.840580
# 9.0      125.750000   39.250000
# 4.0       86.337500  107.850000
# 6.0       97.703125   94.953125

# %%
pkmn_red[pkmn_red.Cluster == 4 ].head()
# Out:
#                    Name    Type 1  Type 2  Total  HP  Attack  Defense  \
# #
# 6             Charizard      Fire  Flying    534  78      84       78
# 18  PidgeotMega Pidgeot    Normal  Flying    579  83      80       80
# 26               Raichu  Electric     NaN    485  60      90       55
# 38            Ninetales      Fire     NaN    505  73      76       75
# 49             Venomoth       Bug  Poison    450  70      65       60
#
#     Sp. Atk  Sp. Def  Speed  Cluster
# #
# 6       109       85    100        4
# 18      135       80    121        4
# 26       90       80    110        4
# 38       81      100    100        4
# 49       90       75     90        4

# %%
pkmn_red[pkmn_red.Cluster == 5 ].head()
# Out:
#         Name  Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# #
# 10  Caterpie     Bug     NaN    195  45      30       35       20       20
# 11   Metapod     Bug     NaN    205  50      20       55       25       25
# 13    Weedle     Bug  Poison    195  40      35       30       20       20
# 14    Kakuna     Bug  Poison    205  45      25       50       25       25
# 16    Pidgey  Normal  Flying    251  40      45       40       35       35
#
#     Speed  Cluster
# #
# 10     45        5
# 11     30        5
# 13     50        5
# 14     35        5
# 16     56        5

# %% [markdown]
# ### With TSNE

# %%
norm_pkmn = preprocessing.normalize(red_pkmn[["Attack","Defense","Sp. Atk", "Sp. Def","Speed"]])
scaled = preprocessing.scale(norm_pkmn)

# %%
pure_sne = TSNE()
pkmn_pure_sned = pure_sne.fit_transform(scaled)

# %%
u.elbow_plot(pkmn_pure_sned, 20)

# %%
kmean_with_dr = cl.Kmeans(k = 10)
kmean_with_dr.fit(pkmn_pure_sned)
u.plot(kmean_with_dr)

# %%
types = np.array(red_pkmn["Type 1"].drop_duplicates())
type_list = np.array(red_pkmn["Type 1"])
tsned_with_type =pd.DataFrame(pkmn_pure_sned)
tsned_with_type["Type"] = type_list

# %%
colors_shapes = ["go","rx","bv","gx", "co", "mv","yx","g^","m*","rh","mX","kD","wo","wD","rP","ko","ys","b*"]
dict_type_color = dict(zip(types,colors_shapes))
for i in range(tsned_with_type.shape[0]):
    color = dict_type_color[tsned_with_type.iloc[i,2]]
    plt.plot(tsned_with_type.iloc[i,0],tsned_with_type.iloc[i,1],color)
plt.show()

# %%
pkmn_red_with_dr =pkmn.drop(["Legendary", "Generation"], axis=1)
pkmn_red_with_dr["Cluster"] = kmean_with_dr.labels_

# %%
pkmn_comparer = pkmn_red_with_dr[pkmn_red_with_dr.Cluster == 0].mean(axis = 0)
pkmn_final = pd.DataFrame(pkmn_comparer).T
for i in range(9):
    pkmn_red_with_dr[pkmn_red_with_dr.Cluster == i+1].mean(axis = 0)
    pkmn_final = pkmn_final.append(pd.DataFrame(pkmn_red_with_dr[pkmn_red_with_dr.Cluster == i+1].mean(axis = 0)).T)
pkmn_final.set_index("Cluster")
# Out:
#               Total         HP      Attack     Defense     Sp. Atk  \
# Cluster
# 0.0      399.834783  62.608696   82.165217   58.504348   51.913043
# 1.0      466.232877  76.027397   72.972603   72.945205  105.767123
# 2.0      488.292929  79.080808  101.818182   61.404040  101.797980
# 3.0      403.408451  65.464789   86.169014  110.323944   47.450704
# 4.0      431.530612  67.061224   76.836735   93.836735   66.428571
# 5.0      430.625000  73.214286   52.035714   60.482143   77.892857
# 6.0      436.909091  61.969697   61.606061   57.818182   93.292929
# 7.0      425.689655  66.678161   60.551724   96.540230   60.597701
# 8.0      409.781818  67.563636   64.381818   68.163636   61.690909
# 9.0      447.875000  74.395833  110.833333   75.541667   58.333333
#
#             Sp. Def      Speed
# Cluster
# 0.0       57.782609  86.860870
# 1.0       85.369863  53.150685
# 2.0       62.989899  81.202020
# 3.0       50.436620  43.563380
# 4.0       66.122449  61.244898
# 5.0      101.678571  65.321429
# 6.0       68.606061  93.616162
# 7.0       95.310345  46.011494
# 8.0       73.927273  74.054545
# 9.0       70.250000  58.520833

# %%
pkmn_final.max()
# Out:
# Total      488.292929
# HP          79.080808
# Attack     110.833333
# Defense    110.323944
# Sp. Atk    105.767123
# Sp. Def    101.678571
# Speed       93.616162
# Cluster      9.000000
# dtype: float64

# %% [markdown]
# 3,3,5,0,6,4,2

# %% [markdown]
# ## PBMC Dataset

# %% [markdown]
# ## Creating GIFs
