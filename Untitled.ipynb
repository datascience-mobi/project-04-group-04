# %%
from WWDK_Package.MbKmeans import MiniBatchKMeans
# Out:
# C:\Users\Marilena\Anaconda3\lib\site-packages\h5py\__init__.py:72: UserWarning: h5py is running against HDF5 1.10.2 when it was built against 1.10.3, this may cause problems
#   '{0}.{1}.{2}'.format(*version.hdf5_built_version_tuple)

# %%
import numpy as np

# %%
X = np.concatenate([
    0.1 * np.random.rand() * np.random.randn(1000, 2) + 1 * np.random.rand(2)
    for idx in range(7)
], axis=0)

# %%
from matplotlib import pyplot as plt
plt.scatter(X[:, 0], X[:, 1])

# %%
kmeans = MiniBatchKMeans(k=5)

# %%
res = kmeans.fit(X)

# %%
res
# Out:
# (array([[0.06276117, 0.7403136 ],
#         [0.64473026, 0.14370526],
#         [0.36195403, 0.83128808],
#         [0.83459426, 0.44986909],
#         [0.21767825, 0.18482429]]),
#  array([2, 2, 2, ..., 0, 0, 0], dtype=int64))

# %%
plt.scatter(X[:, 0], X[:, 1], c=res[1], cmap="tab10")
